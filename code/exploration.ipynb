# %%
import pandas as pd
import numpy as np

# %%
tagesspiegel = pd.read_csv('../data/tagesspiegel_scraped.csv', low_memory=False, index_col=[0])

# %%
zeit = pd.read_csv('../data/zeit_scraped.csv', low_memory=False, index_col=[0])

# %%
welt = pd.read_csv('../data/welt_scraped.csv', low_memory=False, index_col=[0])

# %%
tagesspiegel
# Out:
#                                                    title  \
# 0                  Die Suche nach dem Wert der Ernährung
# 1      Wer für eine kürzere Quarantäne ist – und wer ...
# 2                                            Corona-Test
# 3                         Der Letzte macht das Licht aus
# 4      Lauterbach deutet kürzere Quarantäne an – ande...
# ...                                                  ...
# 12682              Virus aus Wuhan in Japan festgestellt
# 12683  Erster Todesfall durch neues, Lungenkrankheit ...
# 12684  Neues Virus ist wahrscheinlich Ursache von Lun...
# 12685                         Rätselraten über ein Virus
# 12686            Inzidenz in Berlin steigt wieder leicht
#
#                                                     link  \
# 0      /wirtschaft/vorschlaege-zu-lebensmittelpreisen...
# 1      /politik/welcher-schutz-gegen-omikron-ist-noet...
# 2      https://plus.tagesspiegel.de/wissen/wie-in-ber...
# ...

# %%
zeit
# Out:
#       Unnamed: 0                                              title  \
# 0              0  Handel: "Viele brauchen ja eigentlich nichts m...
# 1              1  DGB-Index Gute Arbeit: An den Kosten im Homeof...
# 2              2  Coronavirus: RKI registriert erstmals wieder l...
# 3              3  Bund-Länder-Runde: Kanzleramtschef fordert Cor...
# 4              4  Corona-Impfung für Kinder: Gesundheitsminister...
# ...          ...                                                ...
# 8808         464            Malaysia: Squash-WM der Männer abgesagt
# 8809         465  Corona-Impfstoff: Moderna rechnet mit geringer...
# 8810         466  Bundesverfassungsgericht: Corona-Ausgangsbesch...
# 8811         467  Koalitionsvertrag: Ein Dokument voller schille...
# 8812         468  "Was jetzt?"-Newsletter: Corona-Maßnahmen, Jac...
#
#                                                    link  \
# 0     https://www.zeit.de/2021/48/handel-adventszeit...
# ...

# %%
welt
# Out:
#       Unnamed: 0                                              title  \
# 0              0     Mitten im Spiel beschimpft Zverev seinen Vater
# 1              1    Seenotretter beschimpfen Kurz als "Baby-Hitler"
# 2              2  Trump beschimpft getöteten General Soleimani a...
# 3              3     Chinesisches Corona-Virus hat die USA erreicht
# 4              4         Was Sie über das Coronavirus wissen müssen
# ...          ...                                                ...
# 7363        7363  Neuer Rekordwert – 1622 neue Coronainfektionen...
# 7364        7364       Hamburger Polizei appelliert an die Vernunft
# 7365        7365  120 Menschen feierten auf Sylt – jetzt warten ...
# 7366        7366  Polizei bedankt sich über Lautsprecher bei "Sp...
# 7367        7367  RKI meldet 42.770 Neuinfektionen – Sieben-Tage...
#
#                                                    link              date  \
# 0     https://www.welt.de/sport/tennis/article204775...  05-01-2020 14:07
# ...

# %%
zeit.iloc[1245,1]
# Out:
# 'Coronavirus: Zahl der Neuinfektionen steigt weiter'
